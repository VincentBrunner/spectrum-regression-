# %% [markdown]
# # Project Summary

# %% [markdown]
# ## Goals:
# Find out to what extend deep learning models are suited to evaluate gas absorbtion spectra, especialy in higher concentrations where too much ligt gets absorbt.
#
# ## Overview:
# * Preprocessing Methods
# * Modeling Process
#     * basic architecture choices
#     * summary of the hyperparameter tuning process
# * Findings and potential further use cases

# %% [markdown]
# ### Collecting/generating Data with simulation/digital created dataset:

# %% [markdown]
# generated a dataset containing spectrums as features and the concentration as labels. Taking the concentration in floating points made it hard to interpret the error and datasets containing just a few thousand samples showed to be too small to achieve low loss.
# So the final dataset containes 100k samples containing of spectrums as features and the concentration in ppm as lables.

# %% [markdown]
# [click to view code](https://github.com/VincentBrunner/spectrum-regression-/blob/main/Dataset%20Generation.ipynb)

# %% [markdown]
# ### Data preprocessing:

# %% [markdown]
# The main preprocessing methods include:
# * cutting the ramps of the spectrums
# * normalizing the spectrums by using scypi butter_lowpass filter and dividing by the ramp
#
# All the mentioned methods lead to the model picking up patterns faster, even tho not allways better.
# #### before preprocessing:

# %% [markdown]
# ![original%20spectrum.png](attachment:original%20spectrum.png)

# %% [markdown]
# #### after preprocessing:

# %% [markdown]
# ![preprocessing%20result.png](attachment:preprocessing%20result.png)

# %% [markdown]
# [click to view code](https://github.com/VincentBrunner/spectrum-regression-/blob/main/Data%20exploration%20and%20preprocessing.ipynb)

# %% [markdown]
# ### Modeling process:
# [code to sample model code](https://github.com/VincentBrunner/spectrum-regression-/blob/main/sample%20model.ipynb)
# #### model, modelarchitecture and loss function choice:
# usage of deep neural network: concidering the features containing of just one array each and the project being about a regression task a deep neural network is the most straight foreward choice. Of cause other model types could be tested in the future but for this project we'll concentrate on deep neural networks.
#
# model architecture choice/test results: comparing diffrent model architectures with each other a model using a rather large amount of neurons per layer and consisting of multiple deep layers showed the best results. Intrestingly using a model containing fewer neurons on the fist and last layers than on the middle seemed to perform a hint better than the conventional big to small architecture. More to how the model changed with time in the hyperparameter tuning section.
#
# loss function choice: the loss function used in the current model is the mean squared error, even tho there were some problems acurring with this type off loss, but more in the hyperparameter tuning section.

# %% [markdown]
# #### hyperparameter tuning
# The goal with tuning the model was on the one hand to try reaching the lowest possible error but mainly to check if using a deep neural network for this task is viable and if yes where it's strengts and potential use cases lie. So from time to time the trained models were tested even further by testing them on a 2000 samples large test data set and analysing the percential deviation in regard to the concentration. This allowed to find weaknesses and strenghts that couldn't be seen with just the final mean squared error the model achived after training.
# The first main issue that accured after testing a model with relatively low mse can be seen clearly by making a scatterplot of the percential deviations per concentration:

# %% [markdown]
# ![error%20model%202.png](attachment:error%20model%202.png)

# %% [markdown]
# From this testing it came clear that the percential deviation of predicted small concentrations was way higher than the  of predicted high concentrations. With deviations of around 70% this was way to high but didn't influence the mse much due to it not looking for percential deviation. So this lead me to using the mean absolute percentage error with the optimizer:

# %% [markdown]
# ![error%20model%208.png](attachment:error%20model%208.png)

# %% [markdown]
# After some tuning 2 major issues were dicovered: The error couldn't be reduced similar to earlyer atempts using the mse and when further testing the model(see plot) the same pattern like the last time accured, just with a higher concistancy of deviation per ppm. So from this we concluded the high percential deviation in the lower concentrations being caused by something else and not the wrong error being used for optimisation. After discovering this the mse was again used for optimisation but with the mape as metrics. This way it was possible to continue tuning the model with the better working mse but still monitoring the percential error without going through the detailed testing process everytime.
# In fact with increasing the model size and decreasing the learning rate better performance with less impactfull outliers could be achieved.
# Increasing the model size showed to improve both mse and mape.
# Intrestingly decreasing the learning rate at a certain point stopped improving the mse but continued to improve the mappe:

# %% [markdown]
# large model size(137,873,161 Trainable params)and learning rate of 0.00001:
# Mean squared error = 0.13450007140636444, mean absolute percentage error: 1.5031
# ![comparison%201.1-2.png](attachment:comparison%201.1-2.png)

# %% [markdown]
#  same model size, lower learning rate: Mean squared error = 0.15346722304821014, mean absolute percentage error: 0.8752
# ![comparison%201.2-2.png](attachment:comparison%201.2-2.png)

# %% [markdown]
# lowering the learning rate further than a certain point lead to the interquartal range getting larger and the mse getting worse but improved the amount and impact of outliers when looking at percential deviation:

# %% [markdown]
# ![comparison%202.1.png](attachment:comparison%202.1.png)

# %% [markdown]
# ![comparison%202.2-2.png](attachment:comparison%202.2-2.png)

# %% [markdown]
# [click to view code of the model performance comparison above](https://github.com/VincentBrunner/spectrum-regression-/blob/main/comparison%20higher%20learning%20rate(model%2016%2B17).ipynb)
