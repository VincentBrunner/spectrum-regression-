# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
test_data = pd.read_parquet("model_2_test.parquet")

# %%
print(test_data.head())
print(test_data.describe())
# Out:
#      conc  prediction
# 0   85.54   85.633858
# 1   59.60   59.574562
# 2  195.03  195.218552
# 3  129.63  128.788818
# 4   86.78   87.215836
#               conc   prediction
# count  2000.000000  2000.000000
# mean    100.246155   100.478554
# std      57.464287    57.447929
# min       1.050000     1.075571
# 25%      51.830000    52.089210
# 50%      99.950000   100.003006
# 75%     148.990000   148.935043
# max     199.990000   199.602386

# %%
sns.scatterplot(test_data["conc"], test_data["prediction"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='conc', ylabel='prediction'>

# %%
#percential_deviation = lambda x, y: abs(((y/x)*100)-100)
percential_deviation = lambda x, y: abs(((y-x)/x)*100)

# %%
test_data["percential deviation"] = [percential_deviation(*a) for a in tuple(zip(test_data["conc"], test_data["prediction"]))]

# %%
print(test_data.head())
print(test_data.describe())
# Out:
#      conc  prediction  percential deviation
# 0   85.54   85.633858              0.109724
# 1   59.60   59.574562              0.042681
# 2  195.03  195.218552              0.096678
# 3  129.63  128.788818              0.648910
# 4   86.78   87.215836              0.502230
#               conc   prediction  percential deviation
# count  2000.000000  2000.000000           2000.000000
# mean    100.246155   100.478554              0.957035
# std      57.464287    57.447929              3.257195
# min       1.050000     1.075571              0.000705
# 25%      51.830000    52.089210              0.172875
# 50%      99.950000   100.003006              0.348647
# 75%     148.990000   148.935043              0.671219
# max     199.990000   199.602386             70.712203

# %%
sns.scatterplot(test_data["conc"], test_data["percential deviation"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='conc', ylabel='percential deviation'>
